# %% [markdown]
# <a href="https://colab.research.google.com/github/Wellington-wbs/Trabalho-Python/blob/main/Trabalho_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importando os pacotes
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#apresentando os dados
csv_url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/image/segmentation.data'

# %%
#importando os dados do item 2
df = pd.read_csv(csv_url, skiprows=2, index_col=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   return func(*args, **kwargs)

# %%
#apresentando os 5 primeiros registros
df.head(5)
# Out:
#   REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# 0           BRICKFACE                140.0               125.0
# 1           BRICKFACE                188.0               133.0
# 2           BRICKFACE                105.0               139.0
# 3           BRICKFACE                 34.0               137.0
# 4           BRICKFACE                 39.0               111.0
#
#    SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  VEDGE-SD  \
# 0                     9                   0.0         0.0  0.277778
# 1                     9                   0.0         0.0  0.333333
# 2                     9                   0.0         0.0  0.277778
# 3                     9                   0.0         0.0  0.500000
# 4                     9                   0.0         0.0  0.722222
#
#    HEDGE-MEAN  HEDGE-SD  INTENSITY-MEAN  RAWRED-MEAN  RAWBLUE-MEAN  \
# 0    0.062963  0.666667        0.311111     6.185185      7.333334
# ...

# %%
#apresentando as colunas
df.columns
# Out:
# Index(['REGION-CENTROID-COL', 'REGION-CENTROID-ROW', 'REGION-PIXEL-COUNT',
#        'SHORT-LINE-DENSITY-5', 'SHORT-LINE-DENSITY-2', 'VEDGE-MEAN',
#        'VEDGE-SD', 'HEDGE-MEAN', 'HEDGE-SD', 'INTENSITY-MEAN', 'RAWRED-MEAN',
#        'RAWBLUE-MEAN', 'RAWGREEN-MEAN', 'EXRED-MEAN', 'EXBLUE-MEAN',
#        'EXGREEN-MEAN', 'VALUE-MEAN', 'SATURATION-MEAN', 'HUE-MEAN'],
#       dtype='object')

# %%
#apresentando os tipos de dados das colunas
df.dtypes
# Out:
# REGION-CENTROID-COL      object
# REGION-CENTROID-ROW     float64
# REGION-PIXEL-COUNT      float64
# SHORT-LINE-DENSITY-5      int64
# SHORT-LINE-DENSITY-2    float64
# VEDGE-MEAN              float64
# VEDGE-SD                float64
# HEDGE-MEAN              float64
# HEDGE-SD                float64
# INTENSITY-MEAN          float64
# RAWRED-MEAN             float64
# RAWBLUE-MEAN            float64
# RAWGREEN-MEAN           float64
# EXRED-MEAN              float64
# EXBLUE-MEAN             float64
# EXGREEN-MEAN            float64
# VALUE-MEAN              float64
# SATURATION-MEAN         float64
# HUE-MEAN                float64
# dtype: object

# %%
#apresentando análise
df.describe
# Out:
# <bound method NDFrame.describe of     REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# 0             BRICKFACE                140.0               125.0
# 1             BRICKFACE                188.0               133.0
# 2             BRICKFACE                105.0               139.0
# 3             BRICKFACE                 34.0               137.0
# 4             BRICKFACE                 39.0               111.0
# ..                  ...                  ...                 ...
# 205               GRASS                 36.0               243.0
# 206               GRASS                186.0               218.0
# 207               GRASS                197.0               236.0
# 208               GRASS                208.0               240.0
# 209               GRASS                223.0               185.0
#
#      SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  VEDGE-SD  \
# 0                       9              0.000000         0.0  0.277778
# ...

# %%
#exlcuindo dados
df.drop(207)
# Out:
#     REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# 0             BRICKFACE                140.0               125.0
# 1             BRICKFACE                188.0               133.0
# 2             BRICKFACE                105.0               139.0
# 3             BRICKFACE                 34.0               137.0
# 4             BRICKFACE                 39.0               111.0
# ..                  ...                  ...                 ...
# 204               GRASS                237.0               191.0
# 205               GRASS                 36.0               243.0
# 206               GRASS                186.0               218.0
# 208               GRASS                208.0               240.0
# 209               GRASS                223.0               185.0
#
#      SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  VEDGE-SD  \
# 0                       9              0.000000         0.0  0.277778
# ...

# %%
#apresentando histograma
df['REGION-CENTROID-ROW'].plot.hist()

# %%
#concluindo
data = df.shape
print(data, 'Como podemos ver, o DataFrame voltou a ter 210 linhas mesmo após excluir a linha número 207,\n isso ocorre pois por padrão, as operações efetuadas em um DataFrame não afetam ele, ao remover uma linha\n o que o Pandas faz é devolver um novo DataFrame sem a linha, mantendo o original intacto')
# Out:
# (210, 19) Como podemos ver, o DataFrame voltou a ter 210 linhas mesmo após excluir a linha número 207,
#  isso ocorre pois por padrão, as operações efetuadas em um DataFrame não afetam ele, ao remover uma linha
#  o que o Pandas faz é devolver um novo DataFrame sem a linha, mantendo o original intacto
